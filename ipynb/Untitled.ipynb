# %%
import tkinter as tk
from tkinter import *
from pandas import DataFrame
from matplotlib import pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
import pickle
from sklearn.utils import resample
# Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, auc, roc_curve

# Validation
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.pipeline import Pipeline, make_pipeline

# Tuning
#from sklearn.model_selection import GridSearchCV

# Feature Extraction
#from sklearn.feature_selection import RFE

# Preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, Binarizer, LabelEncoder

# Models
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Ensembles
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("C:\\Users\\Admin\\Desktop\\CSV\\prediction\\humid.csv")
df=dataset.head(10)

data1 = {'Original Data': [df['Original Data']],
         'Prediction': [41.45533679,43.70945057,40.69299545,44.2286482,46.71493561,40.69848049,
41.97453442,45.96356435,44.46082183,46.25058836,43.94162419,49.72042065]
        }
df1 = DataFrame(data1,columns=['Original data','Prediction'])

data2 = {'Original Data': [48.87500095,60,60.20000076,76.42500114,64.17499924,
                           64.97500038,65.07500172,56.19999886,36.5,37.02499962,64.125,63.90000153],
         'Prediction': [29.58702318,26.71533585,30.45309294,35.87117779,30.72533809,38.16606019,
                        40.32541363,42.49536235,41.18811704,43.12050225,45.24086805,44.63191158]
        }
df2 = DataFrame(data2,columns=['Original data','Prediction'])

data3 = {'Original Data': [1012.8,1019.1,1005.4,1028.7,1013.5,
1003,1030,1015.6,1019.6,1020.8,1015.4,1021],
         'Prediction': [1012.054895,1016.913703,1019.327313,1022.43448,1023.176158,
                        1025.51419,1026.911637,1020.231808,1017.84809,1020.931564,1017.84809,1021.585635]
        }
df3 = DataFrame(data3,columns=['Original Data','Prediction'])

data4 = {'Original Data': [26.3,11.3,24.5,17.4,16.5,34,10.2,20,17.9,12.1,19.5,19.8],
         'Prediction': [28.13413991,24.27790022,22.41091047,20.26974954,19.09746185,
                        22.34310566,21.57097214,22.81254061,19.09746185,15.357931055,17.99297898,17.29012624]
        }
df4 = DataFrame(data4,columns=['Original Data','Prediction'])

df = pd.read_csv('C:\\Users\\Admin\\Desktop\\ipyndb\\Crop-Recommender-main\\Crop_recommendation.csv')

# %%
def read_in_and_split_data(data, target):
    X = data.drop(target, axis=1)
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)
    return X_train, X_test, y_train, y_test

# %%
def plant():
    target ='label'
    X_train, X_test, y_train, y_test = read_in_and_split_data(df, target)
    pipeline = make_pipeline(MinMaxScaler(),  GaussianNB())
    model = pipeline.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    global entry_1,entry_2,entry_3,entry_4,entry_5
    temperature = float(entry_1.get())
    humidity = float(entry_2.get())
    ph = float(entry_3.get())
    AirQuality = float(entry_4.get())
    sample = [temperature, humidity,ph, AirQuality]
    single_sample = np.array(sample).reshape(1,-1)
    pred = model.predict(single_sample)
    name=pred.item().title()
    entry5.set(name)

root= Tk()
root.geometry('1200x500')
root.title("Predictive analysis")
  
figure1 = plt.Figure(figsize=(3,2), dpi=100)
ax1 = figure1.add_subplot(111)
line1 = FigureCanvasTkAgg(figure1, root)
line1.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
df1.plot(kind='line', legend=True, ax=ax1, color='b',marker='o', fontsize=10)
ax1.set_title('Humidity-Original VS Prediction')

figure3 = plt.Figure(figsize=(3,2), dpi=100)
ax3 = figure3.add_subplot(111)
ax3.scatter(df3['Original Data'],df3['Prediction'], color = 'g')
scatter3 = FigureCanvasTkAgg(figure3, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax3.legend(['Prediction']) 
ax3.set_xlabel('Original Data')
ax3.set_title('Pressure-Original VS Prediction')


figure2 = plt.Figure(figsize=(3,2), dpi=100)
ax2 = figure2.add_subplot(111)
line2 = FigureCanvasTkAgg(figure2, root)
line2.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
df2.plot(kind='line', legend=True, ax=ax2, color='b',marker='o', fontsize=10)
ax2.set_title('AirQuality-Original VS Prediction')

figure4 = plt.Figure(figsize=(3,2), dpi=100)
ax4 = figure4.add_subplot(111)
ax4.scatter(df4['Original Data'],df4['Prediction'], color = 'g')
scatter3 = FigureCanvasTkAgg(figure4, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax4.legend(['Prediction']) 
ax4.set_xlabel('Original Data')
ax4.set_title('Temperature-Original VS Prediction')


label_0 = Label(root, text="PLANT SUGGESTIONS", width=20, font=("bold", 20))
label_0.place(x=10, y=20)


label_1 = Label(root, text="temperature", width=20, font=("bold", 10))
label_1.place(x=10, y=100)
entry_1 = Entry(root)
entry_1.place(x=150, y=100)

label_2 = Label(root, text="humidity", width=20, font=("bold", 10))
label_2.place(x=10, y=140)
entry_2 = Entry(root)
entry_2.place(x=150, y=140)

label_3 = Label(root, text="pressure", width=20, font=("bold", 10))
label_3.place(x=10, y=180)
entry_3 = Entry(root)
entry_3.place(x=150, y=180)

label_4 = Label(root, text="AirQuality", width=20, font=("bold", 10))
label_4.place(x=10, y=220)
entry_4 = Entry(root)
entry_4.place(x=150, y=220)

knnButton = Button(root, text='Submit', command=plant, fg='blue')
knnButton.pack()
knnButton.place(x=150, y=300)

entry5=StringVar()
label_5 = Label(root, text="SUITABLE PLANT", width=20, font=("bold", 10))
label_5.place(x=10, y=480)
entry_5 = Entry(root,textvariable=entry5)
entry_5.place(x=150, y=480)

root.mainloop()
